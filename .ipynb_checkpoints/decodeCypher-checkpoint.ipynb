# %% [markdown]
# # Decode cypher text
#
# ### Welcome!
# This notebook can decode cypher text. It uses a DFA created by the method outlined here
# [Extracting Automata from Recurrent Neural Networks Using Queries and Counterexamples](https://arxiv.org/abs/1711.09576).
#
# In this notebook will automatically train an RNN on symplfied set of english, and extract a DFA from that RNN.

# %% [markdown]
# # Code below

# %%
from LSTM import LSTMNetwork
from GRU import GRUNetwork
from RNNClassifier import RNNClassifier
from Training_Functions import make_train_set_for_target,mixed_curriculum_train
from Extraction import extract
import time
from memory_profiler import profile
import FalseWordGenerator as FWG

import ALPHABET_8
ALPHABET = ALPHABET_8.ALPHABET
print (ALPHABET)
# Out:
# ['a', 'e', 'i', 'n', 'o', 'r', 's', 't']

# %%
MEANINGFUL_WORDS = ALPHABET_8.WORDS
MEANINGLESS_WORDS = FWG.generateFalseWords(ALPHABET, MEANINGFUL_WORDS)
def target(w):             
   if w.lower() in MEANINGFUL_WORDS:
      return True
   else:
      return False
    
train_set = {}
train_set.update({w: True for w in MEANINGFUL_WORDS})
train_set.update({w: False for w in MEANINGLESS_WORDS})
print ("made training set of size: " + str(len(train_set)))
print ("of which " + str(len(MEANINGFUL_WORDS)) + str(" are positive"))
print ("of which " + str(len(MEANINGLESS_WORDS)) + str(" are negative"))
# Out:
# made training set of size: 2045
# of which 1031 are positive
# of which 1021 are negative

# %% [markdown]
# # Train and Extract with the optimal network

# %%
rnnOpt = RNNClassifier(ALPHABET,num_layers=3,hidden_dim=50,RNNClass = LSTMNetwork)
# Out:
# The dy.parameter(...) call is now DEPRECATED.
#         There is no longer need to explicitly add parameters to the computation graph.
#         Any used parameter will be added automatically.

# %%
mixed_curriculum_train(rnnOpt,train_set,stop_threshold = 0.01)
# Out:
# ('current average loss is: ', 0.2862459515239678)
# ('current average loss is: ', 0.12729926901303376)

# %%
all_words = sorted(list(train_set.keys()),key=lambda x:len(x))
pos = next((w for w in all_words if rnnOpt.classify_word(w)==True),None)
neg = next((w for w in all_words if rnnOpt.classify_word(w)==False),None)
starting_examples = [w for w in [pos,neg] if not None == w]

# %%
rnnOpt.renew()

# %%
dfaOpt = extract(rnnOpt,time_limit = 60, initial_split_depth = 10, starting_examples = starting_examples)
# Out:
# provided counterexamples are: ['an', 'ei']
# obs table refinement took 0.001
# guided starting equivalence query for DFA of size 2
# ['', 'a']
# refining, H size is 1
# <Quantisations.SVMDecisionTreeNode object at 0x00000265463A6A20>
# split wasn't perfect: gotta start over
# ['a', 'e']
# ['n', 'r']
# ['ar', 'at']
# ['ar', 'at', 'ie']
# returning counterexample of length 2:		in, this counterexample is accepted by the given RNN.
# equivalence checking took: 0.7060162440000113
# obs table refinement took 0.056
# guided starting equivalence query for DFA of size 8
# ['a', 'e']
# ['n', 'r']
# returning counterexample of length 2:		ro, this counterexample is accepted by the given RNN.
# equivalence checking took: 0.0984325780000006
# obs table refinement took 0.53
# guided starting equivalence query for DFA of size 26
# ['a', 'e']
# ['n', 'r']
# refining, H size is 1
# <Quantisations.SVMDecisionTreeNode object at 0x0000026547770240>
# ['ar', 'at']
# refining, H size is 1
# <Quantisations.SVMDecisionTreeNode object at 0x00000265478201D0>
# ['at', 'ie']
# refining, H size is 1
# <Quantisations.SVMDecisionTreeNode object at 0x00000265478D8860>
# ['na', 'ne']
# refining, H size is 1
# <Quantisations.SVMDecisionTreeNode object at 0x00000265477AD390>
# ['nn', 'nr']
# ['na', 'ns']
# refining, H size is 1
# <Quantisations.SVMDecisionTreeNode object at 0x00000265478D8828>
# ['nn', 'nr', 'nt']
# ['aa', 'oe']
# ['oi', 'oo']
# ['on', 'or']
# returning counterexample of length 3:		ont, this counterexample is accepted by the given RNN.
# equivalence checking took: 1.1114446089999888
# obs table refinement took 0.953
# guided starting equivalence query for DFA of size 47
# ['a', 'e']
# ['nn', 'nr']
# ['nn', 'nr', 'nt']
# ['aa', 'oe']
# ['oi', 'oo']
# ['on', 'or']
# returning counterexample of length 4:		orta, this counterexample is rejected by the given RNN.
# equivalence checking took: 0.04004757200002018
# obs table refinement took 9.19
# guided starting equivalence query for DFA of size 182
# ['a', 'e']
# ['nn', 'nr']
# ['nn', 'nr', 'nt']
# ['aa', 'oe']
# ['oi', 'oo']
# ['on', 'or']
# returning counterexample of length 4:		orse, this counterexample is rejected by the given RNN.
# equivalence checking took: 0.036842979999988756
# obs table timed out
# observation table timed out during refinement
# overall guided extraction time took: 60.00237859799998
# generated counterexamples were: (format: (counterexample, counterexample generation time))
# ('in', 0.7060162440000113)
# ('ro', 0.0984325780000006)
# ('ont', 1.1114446089999888)
# ('orta', 0.04004757200002018)
# ('orse', 0.036842979999988756)

# %% [markdown]
# # Cypher some messages

# %%
import cypher_creation as c
#a,e,i,n,o,r,s,t
messageOne = 'tea is rotten'
messageTwo = 'no rest eat'
messageThree = 'stone it not'

cypher1 = c.rotate_sentence(messageOne, ALPHABET)
cypher2 = c.rotate_sentence(messageTwo, ALPHABET)
cypher3 = c.rotate_sentence(messageThree, ALPHABET)

print(cypher1)
print(cypher2)
print(cypher3)
# Out:
# tea is rotten
# no rest eat
# stone it not
# aie nt sraaio
# or sita iea
# taroi na ora

# %%
import Rotation_Checker as RCT
RCT.rtCyChecker(cypher1, ALPHABET, rnnOpt, dfaOpt)        # Call above functions
RCT.rtCyChecker(cypher2, ALPHABET, rnnOpt, dfaOpt)
RCT.rtCyChecker(cypher3, ALPHABET, rnnOpt, dfaOpt)
# Out:
# Try message in following list
#  [['eni', 'oa', 'tseenr'], ['ion', 're', 'atiios'], ['nro', 'si', 'eannrt'], ['osr', 'tn', 'ieoosa'], ['rts', 'ao', 'nirrte'], ['sat', 'er', 'onssai'], ['tea', 'is', 'rotten']]
# Cyphered Message is English  ion re atiios in RNN
# Cyphered Message is English  tea is rotten in RNN
# RNN execution time 0.003988981246948242
# Cyphered Message is English  tea is rotten in DFA
# DFA execution time 0.0
# Try message in following list
#  [['rs', 'tnae', 'nie'], ['st', 'aoei', 'oni'], ['ta', 'erin', 'ron'], ['ae', 'isno', 'sro'], ['ei', 'ntor', 'tsr'], ['in', 'oars', 'ats'], ['no', 'rest', 'eat']]
# Cyphered Message is English  no rest eat in RNN
# RNN execution time 0.003988981246948242
# 3 out of  3 words is English
# Cyphered Message is English  ae isno sro in DFA
# DFA execution time 0.0
# Try message in following list
#  [['aesrn', 'oe', 'rse'], ['eitso', 'ri', 'sti'], ['inatr', 'sn', 'tan'], ['noeas', 'to', 'aeo'], ['oriet', 'ar', 'eir'], ['rsnia', 'es', 'ins'], ['stone', 'it', 'not']]
# Cyphered Message is English  stone it not in RNN
# RNN execution time 0.0049877166748046875
# Cyphered Message is English  eitso ri sti in DFA
# Cyphered Message is English  oriet ar eir in DFA
# Cyphered Message is English  rsnia es ins in DFA
# Cyphered Message is English  stone it not in DFA
# DFA execution time 0.0
# (True, True)

# %%
import accuracyChecker as AC
AC.accuracyChecker(MEANINGFUL_WORDS, ALPHABET, rnnOpt, dfaOpt)
# Out:
# serer retention tie erin steatornis
# Try message in following list
#  [['antnt', 'tnenreosr', 'eon', 'ntor', 'aeniestroa'], ['eoaoa', 'aoiosirts', 'iro', 'oars', 'eionitasre'], ['irere', 'ernrtnsat', 'nsr', 'rest', 'inronaetsi'], ['nsisi', 'isosaotea', 'ots', 'sita', 'nosroeiatn'], ['otntn', 'ntrteraie', 'rat', 'tnae', 'ortsrineao'], ['raoao', 'oasaiseni', 'sea', 'aoei', 'rsatsnoier'], ['serer', 'retention', 'tie', 'erin', 'steatornis']]
# Cyphered Message is English  serer retention tie erin steatornis in RNN
# RNN execution time 0.013962268829345703
# 5 out of  5 words is English
# Cyphered Message is English  serer retention tie erin steatornis in DFA
# DFA execution time 0.000997304916381836
# WOW
# area neritina rennin asterion arete
# Try message in following list
#  [['itni', 'rntoeori', 'tnrror', 'iaentosr', 'itnen'], ['naon', 'soarirsn', 'aossrs', 'neioarts', 'naoio'], ['oero', 'tresnsto', 'erttst', 'oinresat', 'oernr'], ['risr', 'asitotar', 'isaata', 'rnositea', 'risos'], ['snts', 'etnaraes', 'nteeae', 'sortnaie', 'sntrt'], ['toat', 'iaoeseit', 'oaiiei', 'trsaoeni', 'toasa'], ['area', 'neritina', 'rennin', 'asterion', 'arete']]
# Cyphered Message is English  area neritina rennin asterion arete in RNN
# RNN execution time 0.01296544075012207
# Cyphered Message is English  area neritina rennin asterion arete in DFA
# DFA execution time 0.0
# astarte tortoise terrasse renter norn
# Try message in following list
#  [['iaeiten', 'estesoan', 'enttiaan', 'tnrent', 'rstr'], ['neinaio', 'itaitreo', 'ioaaneeo', 'aosioa', 'stas'], ['oinoenr', 'naenasir', 'nreeoiir', 'ertnre', 'taet'], ['rnorios', 'oeioetns', 'osiirnns', 'isaosi', 'aeia'], ['sorsnrt', 'rinriaot', 'rtnnsoot', 'ntertn', 'eine'], ['trstosa', 'snosnera', 'saootrra', 'oaisao', 'inoi'], ['astarte', 'tortoise', 'terrasse', 'renter', 'norn']]
# Cyphered Message is English  astarte tortoise terrasse renter norn in RNN
# RNN execution time 0.01994609832763672
# 5 out of  5 words is English
# Cyphered Message is English  oinoenr naenasir nreeoiir ertnre taet in DFA
# DFA execution time 0.0
# setaria ester steer nero strontianite
# Try message in following list
#  [['aneitoi', 'naent', 'aennt', 'rnts', 'aetsreoiroen'], ['eoinarn', 'oeioa', 'eiooa', 'soat', 'eiatsirnsrio'], ['irnoeso', 'rinre', 'inrre', 'trea', 'ineatnsotsnr'], ['nsoritr', 'snosi', 'nossi', 'asie', 'noieaotratos'], ['otrsnas', 'tortn', 'orttn', 'etni', 'ornieraseart'], ['rastoet', 'arsao', 'rsaao', 'iaon', 'rsonisetiesa'], ['setaria', 'ester', 'steer', 'nero', 'strontianite']]
# Cyphered Message is English  setaria ester steer nero strontianite in RNN
# RNN execution time 0.017717599868774414
# 5 out of  5 words is English
# Cyphered Message is English  setaria ester steer nero strontianite in DFA
# DFA execution time 0.0
# sinornis stenosis steatite asian sinornis
# Try message in following list
#  [['aorstroa', 'aenrsaoa', 'aenieoen', 'iaoir', 'aorstroa'], ['erstasre', 'eiostere', 'eionirio', 'nerns', 'erstasre'], ['istaetsi', 'inrtaisi', 'inronsnr', 'oisot', 'istaetsi'], ['ntaeiatn', 'nosaentn', 'nosrotos', 'rntra', 'ntaeiatn'], ['oaeineao', 'orteioao', 'ortsrart', 'soase', 'oaeineao'], ['reinoier', 'rsainrer', 'rsatsesa', 'treti', 'reinoier'], ['sinornis', 'stenosis', 'steatite', 'asian', 'sinornis']]
# Cyphered Message is English  sinornis stenosis steatite asian sinornis in RNN
# RNN execution time 0.0
# 5 out of  5 words is English
# Cyphered Message is English  reinoier rsainrer rsatsesa treti reinoier in DFA
# DFA execution time 0.0
# runtimes are equal
# airiness nasion testis sine innate
# Try message in following list
#  [['iotornaa', 'riaosr', 'enaeoa', 'aorn', 'orrien'], ['nrarsoee', 'snerts', 'ioeire', 'erso', 'rssnio'], ['osestrii', 'toisat', 'nrinsi', 'istr', 'sttonr'], ['rtitasnn', 'arntea', 'osnotn', 'ntas', 'taaros'], ['sanaetoo', 'esoaie', 'rtorao', 'oaet', 'aeesrt'], ['teoeiarr', 'itreni', 'sarser', 'reia', 'eiitsa'], ['airiness', 'nasion', 'testis', 'sine', 'innate']]
# Cyphered Message is English  airiness nasion testis sine innate in RNN
# RNN execution time 0.015620708465576172
# Cyphered Message is English  airiness nasion testis sine innate in DFA
# DFA execution time 0.0
# erosion retreatant tenia steer sonsie
# Try message in following list
#  [['ntsaosr', 'tnetnieire', 'enroi', 'aennt', 'asraon'], ['oaterts', 'aoiaoninsi', 'iosrn', 'eiooa', 'etsero'], ['reaisat', 'erneronotn', 'nrtso', 'inrre', 'iatisr'], ['sientea', 'isoisrorao', 'osatr', 'nossi', 'neants'], ['tnioaie', 'ntrntsrser', 'rteas', 'orttn', 'oieoat'], ['aonreni', 'oasoatstis', 'saiet', 'rsaao', 'rnirea'], ['erosion', 'retreatant', 'tenia', 'steer', 'sonsie']]
# Cyphered Message is English  erosion retreatant tenia steer sonsie in RNN
# RNN execution time 0.01604318618774414
# 5 out of  5 words is English
# Cyphered Message is English  erosion retreatant tenia steer sonsie in DFA
# DFA execution time 0.0
# seta eat oasis rot soiree
# Try message in following list
#  [['anei', 'nie', 'siaoa', 'tse', 'asotnn'], ['eoin', 'oni', 'tnere', 'ati', 'etraoo'], ['irno', 'ron', 'aoisi', 'ean', 'iaserr'], ['nsor', 'sro', 'erntn', 'ieo', 'netiss'], ['otrs', 'tsr', 'isoao', 'nir', 'oiantt'], ['rast', 'ats', 'ntrer', 'ons', 'rneoaa'], ['seta', 'eat', 'oasis', 'rot', 'soiree']]
# Cyphered Message is English  seta eat oasis rot soiree in RNN
# RNN execution time 0.015623092651367188
# 5 out of  5 words is English
# Cyphered Message is English  seta eat oasis rot soiree in DFA
# DFA execution time 0.0
# it stationariness tennessee inanna nonresistant
# Try message in following list
#  [['oe', 'aeieosritornaa', 'enrrnaann', 'orirri', 'rsrtnaoaeire'], ['ri', 'einirtsnarsoee', 'iossoeeoo', 'rsnssn', 'stsaoereinsi'], ['sn', 'inonsatoestrii', 'nrttriirr', 'stotto', 'taterisinotn'], ['to', 'norotearitasnn', 'osaasnnss', 'taraar', 'aeaisntnorao'], ['ar', 'orsraiesnaetoo', 'rteetoott', 'aesees', 'eientoaorser'], ['es', 'rstsenitoeiarr', 'saiiarraa', 'eitiit', 'inioarerstis'], ['it', 'stationariness', 'tennessee', 'inanna', 'nonresistant']]
# Cyphered Message is English  it stationariness tennessee inanna nonresistant in RNN
# RNN execution time 0.015621662139892578
# Cyphered Message is English  it stationariness tennessee inanna nonresistant in DFA
# DFA execution time 0.0
# initiation torino aorta sanitation stater
# Try message in following list
#  [['oroeoieosr', 'estors', 'istei', 'airoeieosr', 'aeient'], ['rsrirnirts', 'itarst', 'ntain', 'ensrinirts', 'einioa'], ['stsnsonsat', 'naesta', 'oaeno', 'iotsnonsat', 'inonre'], ['tatotrotea', 'oeitae', 'reior', 'nratorotea', 'norosi'], ['aearasraie', 'rinaei', 'sinrs', 'osearsraie', 'orsrtn'], ['eiesetseni', 'snoein', 'tnost', 'rtiestseni', 'rstsao'], ['initiation', 'torino', 'aorta', 'sanitation', 'stater']]
# Cyphered Message is English  initiation torino aorta sanitation stater in RNN
# RNN execution time 0.015620946884155273
# 5 out of  5 words is English
# Cyphered Message is English  initiation torino aorta sanitation stater in DFA
# DFA execution time 0.0
# isere raiser ranter irani art
# Try message in following list
#  [['oantn', 'tioant', 'tirent', 'otiro', 'ite'], ['reoao', 'anreoa', 'ansioa', 'ransr', 'nai'], ['sirer', 'eosire', 'eotnre', 'seots', 'oen'], ['tnsis', 'irtnsi', 'iraosi', 'tirat', 'rio'], ['aotnt', 'nsaotn', 'nsertn', 'ansea', 'snr'], ['eraoa', 'oterao', 'otisao', 'eotie', 'tos'], ['isere', 'raiser', 'ranter', 'irani', 'art']]
# Cyphered Message is English  isere raiser ranter irani art in RNN
# RNN execution time 0.015622377395629883
# Cyphered Message is English  isere raiser ranter irani art in DFA
# DFA execution time 0.0
# inerrant ans anserine tanoan irons
# Try message in following list
#  [['ornttire', 'ira', 'irantorn', 'eirsir', 'otsra'], ['rsoaansi', 'nse', 'nseoarso', 'instns', 'ratse'], ['streeotn', 'oti', 'otirestr', 'notaot', 'seati'], ['tasiirao', 'ran', 'ransitas', 'oraera', 'tiean'], ['aetnnser', 'seo', 'seotnaet', 'rseise', 'anieo'], ['eiaootis', 'tir', 'tiraoeia', 'stinti', 'eonir'], ['inerrant', 'ans', 'anserine', 'tanoan', 'irons']]
# Cyphered Message is English  inerrant ans anserine tanoan irons in RNN
# RNN execution time 0.0
# 5 out of  5 words is English
# Cyphered Message is English  rsoaansi nse nseoarso instns ratse in DFA
# DFA execution time 0.0
# runtimes are equal
# airiness orites aerie intension ionian
# Try message in following list
#  [['iotornaa', 'stoena', 'inton', 'orenraosr', 'osroir'], ['nrarsoee', 'tarioe', 'noaro', 'rsioserts', 'rtsrns'], ['osestrii', 'aesnri', 'oresr', 'stnrtisat', 'satsot'], ['rtitasnn', 'eitosn', 'rsits', 'taosantea', 'teatra'], ['sanaetoo', 'inarto', 'stnat', 'aerteoaie', 'aiease'], ['teoeiarr', 'noesar', 'taoea', 'eisaireni', 'enieti'], ['airiness', 'orites', 'aerie', 'intension', 'ionian']]
# Cyphered Message is English  airiness orites aerie intension ionian in RNN
# RNN execution time 0.031462907791137695
# Cyphered Message is English  airiness orites aerie intension ionian in DFA
# DFA execution time 0.0
# tenoroon anne satori rooter taoist
# Try message in following list
#  [['enrstssr', 'irrn', 'aiesto', 'tssent', 'eisoae'], ['iostatts', 'nsso', 'enitar', 'attioa', 'intrei'], ['nrtaeaat', 'ottr', 'ionaes', 'eaanre', 'noasin'], ['osaeieea', 'raas', 'nroeit', 'ieeosi', 'oretno'], ['rteiniie', 'seet', 'osrina', 'niirtn', 'rsiaor'], ['sainonni', 'tiia', 'rtsnoe', 'onnsao', 'stners'], ['tenoroon', 'anne', 'satori', 'rooter', 'taoist']]
# Cyphered Message is English  tenoroon anne satori rooter taoist in RNN
# RNN execution time 0.012965202331542969
# Cyphered Message is English  tenoroon anne satori rooter taoist in DFA
# DFA execution time 0.0
# nonresonant enteron one aeon renoir
# Try message in following list
#  [['rsrtnasrire', 'nrentsr', 'srn', 'insr', 'tnrsot'], ['stsaoetsnsi', 'osioats', 'tso', 'nots', 'aostra'], ['tateriatotn', 'rtnreat', 'atr', 'orat', 'ertase'], ['aeaisnearao', 'saosiea', 'eas', 'rsea', 'isaeti'], ['eientoieser', 'tertnie', 'iet', 'stie', 'nteian'], ['inioarnitis', 'aisaoni', 'nia', 'tani', 'oaineo'], ['nonresonant', 'enteron', 'one', 'aeon', 'renoir']]
# Cyphered Message is English  nonresonant enteron one aeon renoir in RNN
# RNN execution time 0.01010274887084961
# 5 out of  5 words is English
# Cyphered Message is English  nonresonant enteron one aeon renoir in DFA
# DFA execution time 0.0
# ionia ernst tiro assonant ranter
# Try message in following list
#  [['osroi', 'ntrae', 'eots', 'iaasrire', 'tirent'], ['rtsrn', 'oasei', 'irat', 'neetsnsi', 'ansioa'], ['satso', 'retin', 'nsea', 'oiiatotn', 'eotnre'], ['teatr', 'siano', 'otie', 'rnnearao', 'iraosi'], ['aieas', 'tneor', 'rani', 'sooieser', 'nsertn'], ['eniet', 'aoirs', 'seon', 'trrnitis', 'otisao'], ['ionia', 'ernst', 'tiro', 'assonant', 'ranter']]
# Cyphered Message is English  ionia ernst tiro assonant ranter in RNN
# RNN execution time 0.0
# 5 out of  5 words is English
# Cyphered Message is English  eniet aoirs seon trrnitis otisao in DFA
# DFA execution time 0.0
# runtimes are equal
# aerie inertia earnestness teresa sir
# Try message in following list
#  [['inton', 'ornteoi', 'nitrnaernaa', 'entnai', 'aot'], ['noaro', 'rsoairn', 'onasoeisoee', 'ioaoen', 'era'], ['oresr', 'strenso', 'roetrintrii', 'nrerio', 'ise'], ['rsits', 'tasiotr', 'sriasnoasnn', 'osisnr', 'nti'], ['stnat', 'aetnras', 'tsnetoretoo', 'rtntos', 'oan'], ['taoea', 'eiaoset', 'atoiarsiarr', 'saoart', 'reo'], ['aerie', 'inertia', 'earnestness', 'teresa', 'sir']]
# Cyphered Message is English  aerie inertia earnestness teresa sir in RNN
# RNN execution time 0.015623092651367188
# 5 out of  5 words is English
# Cyphered Message is English  aerie inertia earnestness teresa sir in DFA
# DFA execution time 0.0
# sas snot intranet astaire narration
# Try message in following list
#  [['aia', 'arse', 'oretirne', 'iaeiotn', 'rittieosr'], ['ene', 'esti', 'rsiansoi', 'neinrao', 'snaanirts'], ['ioi', 'itan', 'stneotrn', 'oinoser', 'toeeonsat'], ['nrn', 'naeo', 'taoiraso', 'rnortis', 'ariirotea'], ['oso', 'oeir', 'aernsetr', 'sorsant', 'esnnsraie'], ['rtr', 'rins', 'eisotias', 'trsteoa', 'itootseni'], ['sas', 'snot', 'intranet', 'astaire', 'narration']]
# Cyphered Message is English  sas snot intranet astaire narration in RNN
# RNN execution time 0.015620946884155273
# 5 out of  5 words is English
# Cyphered Message is English  sas snot intranet astaire narration in DFA
# DFA execution time 0.0
# rio asserter sinistrorse net sorter
# Try message in following list
#  [['tos', 'iaantent', 'aoroaetstan', 'rne', 'astent'], ['art', 'neeoaioa', 'ersreiataeo', 'soi', 'etaioa'], ['esa', 'oiirenre', 'istsineaeir', 'trn', 'iaenre'], ['ite', 'rnnsiosi', 'ntatnoieins', 'aso', 'neiosi'], ['nai', 'sootnrtn', 'oaeaorninot', 'etr', 'oinrtn'], ['oen', 'trraosao', 'reiersonora', 'ias', 'rnosao'], ['rio', 'asserter', 'sinistrorse', 'net', 'sorter']]
# Cyphered Message is English  rio asserter sinistrorse net sorter in RNN
# RNN execution time 0.01892852783203125
# 5 out of  5 words is English
# Cyphered Message is English  tos iaantent aoroaetstan rne astent in DFA
# DFA execution time 0.0
# intestine tenor sitter anise stationariness
# Try message in following list
#  [['orenaeorn', 'enrst', 'aoeent', 'iroan', 'aeieosritornaa'], ['rsioeirso', 'iosta', 'eriioa', 'nsreo', 'einirtsnarsoee'], ['stnrinstr', 'nrtae', 'isnnre', 'otsir', 'inonsatoestrii'], ['taosnotas', 'osaei', 'ntoosi', 'ratns', 'norotearitasnn'], ['aertoraet', 'rtein', 'oarrtn', 'seaot', 'orsraiesnaetoo'], ['eisarseia', 'saino', 'ressao', 'tiera', 'rstsenitoeiarr'], ['intestine', 'tenor', 'sitter', 'anise', 'stationariness']]
# Cyphered Message is English  intestine tenor sitter anise stationariness in RNN
# RNN execution time 0.020943880081176758
# Cyphered Message is English  intestine tenor sitter anise stationariness in DFA
# DFA execution time 0.0
# toetoe test tito naan reinstate
# Try message in following list
#  [['esnesn', 'enae', 'eoes', 'riir', 'tnoraeien'], ['itoito', 'ioei', 'irit', 'snns', 'aorseinio'], ['narnar', 'nrin', 'nsna', 'toot', 'erstinonr'], ['oesoes', 'osno', 'otoe', 'arra', 'istanoros'], ['ritrit', 'rtor', 'rari', 'esse', 'ntaeorsrt'], ['snasna', 'sars', 'sesn', 'itti', 'oaeirstsa'], ['toetoe', 'test', 'tito', 'naan', 'reinstate']]
# Cyphered Message is English  toetoe test tito naan reinstate in RNN
# RNN execution time 0.010970592498779297
# 5 out of  5 words is English
# Cyphered Message is English  narnar nrin nsna toot erstinonr in DFA
# DFA execution time 0.0
# raisin stone sore sensitiser arsine
# Try message in following list
#  [['tioaor', 'aesrn', 'astn', 'anraoeoant', 'itaorn'], ['anrers', 'eitso', 'etao', 'eoserireoa', 'naerso'], ['eosist', 'inatr', 'iaer', 'irtisnsire', 'oeistr'], ['irtnta', 'noeas', 'neis', 'nsantotnsi', 'rintas'], ['nsaoae', 'oriet', 'oint', 'oteoaraotn', 'snoaet'], ['oterei', 'rsnia', 'rnoa', 'raireserao', 'toreia'], ['raisin', 'stone', 'sore', 'sensitiser', 'arsine']]
# Cyphered Message is English  raisin stone sore sensitiser arsine in RNN
# RNN execution time 0.012965202331542969
# 5 out of  5 words is English
# Cyphered Message is English  raisin stone sore sensitiser arsine in DFA
# DFA execution time 0.0009970664978027344
# WOW
# tontine ensnare assent ionian inosine
# Try message in following list
#  [['esreorn', 'nraritn', 'iaanre', 'osroir', 'orsaorn'], ['itsirso', 'osesnao', 'neeosi', 'rtsrns', 'rsterso'], ['natnstr', 'rtitoer', 'oiirtn', 'satsot', 'staistr'], ['oeaotas', 'sanaris', 'rnnsao', 'teatra', 'taentas'], ['rieraet', 'teoesnt', 'sooter', 'aiease', 'aeioaet'], ['sniseia', 'airitoa', 'trrais', 'enieti', 'einreia'], ['tontine', 'ensnare', 'assent', 'ionian', 'inosine']]
# Cyphered Message is English  tontine ensnare assent ionian inosine in RNN
# RNN execution time 0.0030944347381591797
# 5 out of  5 words is English
# Cyphered Message is English  tontine ensnare assent ionian inosine in DFA
# DFA execution time 0.0
# sensate sarasota orison raster intranet
# Try message in following list
#  [['anraien', 'aitiasei', 'stoasr', 'tiaent', 'oretirne'], ['eosenio', 'enanetin', 'tarets', 'aneioa', 'rsiansoi'], ['irtionr', 'ioeoiano', 'aesiat', 'eoinre', 'stneotrn'], ['nsanros', 'nrirneor', 'eitnea', 'irnosi', 'taoiraso'], ['oteosrt', 'osnsoirs', 'inaoie', 'nsortn', 'aernsetr'], ['rairtsa', 'rtotrnst', 'noerni', 'otrsao', 'eisotias'], ['sensate', 'sarasota', 'orison', 'raster', 'intranet']]
# Cyphered Message is English  sensate sarasota orison raster intranet in RNN
# RNN execution time 0.015622377395629883
# Cyphered Message is English  sensate sarasota orison raster intranet in DFA
# DFA execution time 0.0
# steerer ana seer soonest teras
# Try message in following list
#  [['aenntnt', 'iri', 'annt', 'assrnae', 'entia'], ['eiooaoa', 'nsn', 'eooa', 'ettsoei', 'ioane'], ['inrrere', 'oto', 'irre', 'iaatrin', 'nreoi'], ['nossisi', 'rar', 'nssi', 'neeasno', 'osirn'], ['orttntn', 'ses', 'ottn', 'oiietor', 'rtnso'], ['rsaaoao', 'tit', 'raao', 'rnniars', 'saotr'], ['steerer', 'ana', 'seer', 'soonest', 'teras']]
# Cyphered Message is English  steerer ana seer soonest teras in RNN
# RNN execution time 0.02147197723388672
# 5 out of  5 words is English
# Cyphered Message is English  steerer ana seer soonest teras in DFA
# DFA execution time 0.0
# stare titrator neonate iranian eon
# Try message in following list
#  [['aeitn', 'eoetiest', 'rnsrien', 'otiroir', 'nsr'], ['einao', 'irianita', 'sotsnio', 'ransrns', 'ots'], ['inoer', 'nsneonae', 'tratonr', 'seotsot', 'rat'], ['noris', 'otoiroei', 'asearos', 'tiratra', 'sea'], ['orsnt', 'rarnsrin', 'etiesrt', 'ansease', 'tie'], ['rstoa', 'sesotsno', 'ianitsa', 'eotieti', 'ani'], ['stare', 'titrator', 'neonate', 'iranian', 'eon']]
# Cyphered Message is English  stare titrator neonate iranian eon in RNN
# RNN execution time 0.0052073001861572266
# 5 out of  5 words is English
# Cyphered Message is English  noris otoiroei asearos tiratra sea in DFA
# DFA execution time 0.0
# eastern trait stationariness stairs rate
# Try message in following list
#  [['niaentr', 'etioe', 'aeieosritornaa', 'aeiota', 'tien'], ['oneioas', 'ianri', 'einirtsnarsoee', 'einrae', 'anio'], ['roinret', 'neosn', 'inonsatoestrii', 'inosei', 'eonr'], ['srnosia', 'oirto', 'norotearitasnn', 'nortin', 'iros'], ['tsortne', 'rnsar', 'orsraiesnaetoo', 'orsano', 'nsrt'], ['atrsaoi', 'sotes', 'rstsenitoeiarr', 'rsteor', 'otsa'], ['eastern', 'trait', 'stationariness', 'stairs', 'rate']]
# Cyphered Message is English  eastern trait stationariness stairs rate in RNN
# RNN execution time 0.015623331069946289
# 5 out of  5 words is English
# Cyphered Message is English  niaentr etioe aeieosritornaa aeiota tien in DFA
# DFA execution time 0.0
# sin oat rotarian stressor estrone
# Try message in following list
#  [['aor', 'sie', 'tseitoir', 'aetnaast', 'naetsrn'], ['ers', 'tni', 'atinarns', 'eiaoeeta', 'oeiatso'], ['ist', 'aon', 'eanoesot', 'ineriiae', 'rineatr'], ['nta', 'ero', 'ieoritra', 'noisnnei', 'snoieas'], ['oae', 'isr', 'nirsnase', 'orntooin', 'torniet'], ['rei', 'nts', 'onstoeti', 'rsoarrno', 'arsonia'], ['sin', 'oat', 'rotarian', 'stressor', 'estrone']]
# Cyphered Message is English  sin oat rotarian stressor estrone in RNN
# RNN execution time 0.01679396629333496
# Cyphered Message is English  sin oat rotarian stressor estrone in DFA
# DFA execution time 0.0
# nineties arsine sanitisation state rate
# Try message in following list
#  [['rorneona', 'itaorn', 'airoeoaieosr', 'aeien', 'tien'], ['srsoiroe', 'naerso', 'ensrirenirts', 'einio', 'anio'], ['tstrnsri', 'oeistr', 'iotsnsionsat', 'inonr', 'eonr'], ['atasotsn', 'rintas', 'nratotnrotea', 'noros', 'iros'], ['eaetrato', 'snoaet', 'osearaosraie', 'orsrt', 'nsrt'], ['ieiasear', 'toreia', 'rtiesertseni', 'rstsa', 'otsa'], ['nineties', 'arsine', 'sanitisation', 'state', 'rate']]
# Cyphered Message is English  nineties arsine sanitisation state rate in RNN
# RNN execution time 0.019946575164794922
# Cyphered Message is English  nineties arsine sanitisation state rate in DFA
# DFA execution time 0.0
# essen instantiate retro astor season
# Try message in following list
#  [['naanr', 'oraeireoien', 'tnets', 'iaest', 'aniasr'], ['oeeos', 'rseinsirnio', 'aoiat', 'neita', 'eonets'], ['riirt', 'stinotnsonr', 'ernea', 'oinae', 'iroiat'], ['snnsa', 'tanoraotros', 'isoie', 'rnoei', 'nsrnea'], ['toote', 'aeorserasrt', 'ntrni', 'sorin', 'otsoie'], ['arrai', 'eirstisetsa', 'oason', 'trsno', 'ratrni'], ['essen', 'instantiate', 'retro', 'astor', 'season']]
# Cyphered Message is English  essen instantiate retro astor season in RNN
# RNN execution time 0.013962984085083008
# 5 out of  5 words is English
# Cyphered Message is English  essen instantiate retro astor season in DFA
# DFA execution time 0.0
# essonite reorient roast asserter assistant
# Try message in following list
#  [['naasroen', 'tnstonre', 'tsiae', 'iaantent', 'iaaoaeire'], ['oeetsrio', 'aotarosi', 'atnei', 'neeoaioa', 'neereinsi'], ['riiatsnr', 'eraesrtn', 'eaoin', 'oiirenre', 'oiisinotn'], ['snneatos', 'iseitsao', 'ierno', 'rnnsiosi', 'rnntnorao'], ['tooieart', 'ntinater', 'nisor', 'sootnrtn', 'sooaorser'], ['arrniesa', 'oanoeais', 'ontrs', 'trraosao', 'trrerstis'], ['essonite', 'reorient', 'roast', 'asserter', 'assistant']]
# Cyphered Message is English  essonite reorient roast asserter assistant in RNN
# RNN execution time 0.015956401824951172
# 5 out of  5 words is English
# Cyphered Message is English  naasroen tnstonre tsiae iaantent iaaoaeire in DFA
# DFA execution time 0.0
# arietta inset treasonist inn roarer
# Try message in following list
#  [['itoneei', 'orane', 'etniasroae', 'orr', 'tsitnt'], ['naroiin', 'rseoi', 'iaonetsrei', 'rss', 'atnaoa'], ['oesrnno', 'stirn', 'neroiatsin', 'stt', 'eaoere'], ['ritsoor', 'tanso', 'oisrneatno', 'taa', 'ierisi'], ['snatrrs', 'aeotr', 'rntsoieaor', 'aee', 'nisntn'], ['toeasst', 'eiras', 'soatrniers', 'eii', 'ontoao'], ['arietta', 'inset', 'treasonist', 'inn', 'roarer']]
# Cyphered Message is English  arietta inset treasonist inn roarer in RNN
# RNN execution time 0.012965917587280273
# 5 out of  5 words is English
# Cyphered Message is English  arietta inset treasonist inn roarer in DFA
# DFA execution time 0.0
# raise tinter nester arsenate ass
# Try message in following list
#  [['tioan', 'eorent', 'rnaent', 'itanrien', 'iaa'], ['anreo', 'irsioa', 'soeioa', 'naeosnio', 'nee'], ['eosir', 'nstnre', 'trinre', 'oeirtonr', 'oii'], ['irtns', 'otaosi', 'asnosi', 'rinsaros', 'rnn'], ['nsaot', 'raertn', 'etortn', 'snotesrt', 'soo'], ['otera', 'seisao', 'iarsao', 'toraitsa', 'trr'], ['raise', 'tinter', 'nester', 'arsenate', 'ass']]
# Cyphered Message is English  raise tinter nester arsenate ass in RNN
# RNN execution time 0.011968135833740234
# Cyphered Message is English  raise tinter nester arsenate ass in DFA
# DFA execution time 0.0
# terror taste teens eerie norse
# Try message in following list
#  [['enttst', 'eiaen', 'ennra', 'nnton', 'rstan'], ['ioaata', 'ineio', 'ioose', 'ooaro', 'staeo'], ['nreeae', 'noinr', 'nrrti', 'rresr', 'taeir'], ['osiiei', 'ornos', 'ossan', 'ssits', 'aeins'], ['rtnnin', 'rsort', 'rtteo', 'ttnat', 'einot'], ['saoono', 'strsa', 'saair', 'aaoea', 'inora'], ['terror', 'taste', 'teens', 'eerie', 'norse']]
# Cyphered Message is English  terror taste teens eerie norse in RNN
# RNN execution time 0.0109710693359375
# 5 out of  5 words is English
# Cyphered Message is English  terror taste teens eerie norse in DFA
# DFA execution time 0.0
# notate arrester reentrant taenia tore
# Try message in following list
#  [['rseien', 'ittnaent', 'tnnretire', 'einroi', 'estn'], ['stinio', 'naaoeioa', 'aoosiansi', 'inosrn', 'itao'], ['tanonr', 'oeerinre', 'errtneotn', 'nortso', 'naer'], ['aeoros', 'riisnosi', 'issaoirao', 'orsatr', 'oeis'], ['eirsrt', 'snntortn', 'ntternser', 'rsteas', 'rint'], ['instsa', 'tooarsao', 'oaaisotis', 'staiet', 'snoa'], ['notate', 'arrester', 'reentrant', 'taenia', 'tore']]
# Cyphered Message is English  notate arrester reentrant taenia tore in RNN
# RNN execution time 0.004402637481689453
# 5 out of  5 words is English
# Cyphered Message is English  notate arrester reentrant taenia tore in DFA
# DFA execution time 0.0
# irritation aeration ariose reno eira
# Try message in following list
#  [['ottoeieosr', 'intieosr', 'itosan', 'tnrs', 'noti'], ['raarinirts', 'noanirts', 'narteo', 'aost', 'oran'], ['seesnonsat', 'oreonsat', 'oesair', 'erta', 'rseo'], ['tiitorotea', 'rsirotea', 'ritens', 'isae', 'stir'], ['annarsraie', 'stnsraie', 'snaiot', 'ntei', 'tans'], ['eooestseni', 'taotseni', 'toenra', 'oain', 'aeot'], ['irritation', 'aeration', 'ariose', 'reno', 'eira']]
# Cyphered Message is English  irritation aeration ariose reno eira in RNN
# RNN execution time 0.015622138977050781
# 5 out of  5 words is English
# Cyphered Message is English  tiitorotea rsirotea ritens isae stir in DFA
# DFA execution time 0.0
# orasone torte astir net eats
# Try message in following list
#  [['stiasrn', 'esten', 'iaeot', 'rne', 'niea'], ['tanetso', 'itaio', 'neira', 'soi', 'onie'], ['aeoiatr', 'naenr', 'oinse', 'trn', 'roni'], ['eirneas', 'oeios', 'rnoti', 'aso', 'sron'], ['insoiet', 'rinrt', 'soran', 'etr', 'tsro'], ['notrnia', 'snosa', 'trseo', 'ias', 'atsr'], ['orasone', 'torte', 'astir', 'net', 'eats']]
# Cyphered Message is English  orasone torte astir net eats in RNN
# RNN execution time 0.015621423721313477
# 5 out of  5 words is English
# Cyphered Message is English  orasone torte astir net eats in DFA
# DFA execution time 0.0
# tort nero treat sessions teetertotter
# Try message in following list
#  [['este', 'rnts', 'etnie', 'anaaosra', 'ennenteseent'], ['itai', 'soat', 'iaoni', 'eoeertse', 'iooioaitiioa'], ['naen', 'trea', 'neron', 'iriisati', 'nrrnrenannre'], ['oeio', 'asie', 'oisro', 'nsnntean', 'ossosioeoosi'], ['rinr', 'etni', 'rntsr', 'otooaieo', 'rttrtnrirrtn'], ['snos', 'iaon', 'soats', 'rarrenir', 'saasaosnssao'], ['tort', 'nero', 'treat', 'sessions', 'teetertotter']]
# Cyphered Message is English  tort nero treat sessions teetertotter in RNN
# RNN execution time 0.02047872543334961
# 5 out of  5 words is English
# Cyphered Message is English  naen trea neron iriisati nrrnrenannre in DFA
# DFA execution time 0.0
# ratite saint tastiness tessera teres
# Try message in following list
#  [['tieoen', 'aiore', 'eiaeornaa', 'enaanti', 'entna'], ['anirio', 'enrsi', 'ineirsoee', 'ioeeoan', 'ioaoe'], ['eonsnr', 'iostn', 'noinstrii', 'nriireo', 'nreri'], ['irotos', 'nrtao', 'ornotasnn', 'osnnsir', 'osisn'], ['nsrart', 'osaer', 'rsoraetoo', 'rtootns', 'rtnto'], ['otsesa', 'rteis', 'strseiarr', 'sarraot', 'saoar'], ['ratite', 'saint', 'tastiness', 'tessera', 'teres']]
# Cyphered Message is English  ratite saint tastiness tessera teres in RNN
# RNN execution time 0.01296544075012207
# 5 out of  5 words is English
# Cyphered Message is English  otsesa rteis strseiarr sarraot saoar in DFA
# DFA execution time 0.0
# rosin einstein rooter trotter attorn
# Try message in following list
#  [['tsaor', 'noraenor', 'tssent', 'etseent', 'ieestr'], ['aters', 'orseiors', 'attioa', 'iatiioa', 'niitas'], ['eaist', 'rstinrst', 'eaanre', 'neannre', 'onnaet'], ['ienta', 'stanosta', 'ieeosi', 'oieoosi', 'rooeia'], ['nioae', 'taeortae', 'niirtn', 'rnirrtn', 'srrine'], ['onrei', 'aeirsaei', 'onnsao', 'sonssao', 'tssnoi'], ['rosin', 'einstein', 'rooter', 'trotter', 'attorn']]
# Cyphered Message is English  rosin einstein rooter trotter attorn in RNN
# RNN execution time 0.01296544075012207
# 5 out of  5 words is English
# Cyphered Message is English  rosin einstein rooter trotter attorn in DFA
# DFA execution time 0.0
# tia assassinator rear stone aria
# Try message in following list
#  [['eoi', 'iaaiaaoriest', 'tnit', 'aesrn', 'itoi'], ['irn', 'neeneersnita', 'aona', 'eitso', 'narn'], ['nso', 'oiioiistonae', 'eroe', 'inatr', 'oeso'], ['otr', 'rnnrnntaroei', 'isri', 'noeas', 'ritr'], ['ras', 'soosooaesrin', 'ntsn', 'oriet', 'snas'], ['set', 'trrtrreitsno', 'oato', 'rsnia', 'toet'], ['tia', 'assassinator', 'rear', 'stone', 'aria']]
# Cyphered Message is English  tia assassinator rear stone aria in RNN
# RNN execution time 0.010970354080200195
# Cyphered Message is English  tia assassinator rear stone aria in DFA
# DFA execution time 0.000997304916381836
# WOW
# neat assets ottar stair serration
# Try message in following list
#  [['rnie', 'iaanea', 'seeit', 'aeiot', 'anttieosr'], ['soni', 'neeoie', 'tiina', 'einra', 'eoaanirts'], ['tron', 'oiirni', 'annoe', 'inose', 'ireeonsat'], ['asro', 'rnnson', 'eoori', 'norti', 'nsiirotea'], ['etsr', 'sootro', 'irrsn', 'orsan', 'otnnsraie'], ['iats', 'trrasr', 'nssto', 'rsteo', 'raootseni'], ['neat', 'assets', 'ottar', 'stair', 'serration']]
# Cyphered Message is English  neat assets ottar stair serration in RNN
# RNN execution time 0.010970592498779297
# 5 out of  5 words is English
# Cyphered Message is English  neat assets ottar stair serration in DFA
# DFA execution time 0.0
# estonia tia roost anasa einstein
# Try message in following list
#  [['naesroi', 'eoi', 'tssae', 'iriai', 'noraenor'], ['oeitsrn', 'irn', 'attei', 'nsnen', 'orseiors'], ['rinatso', 'nso', 'eaain', 'otoio', 'rstinrst'], ['snoeatr', 'otr', 'ieeno', 'rarnr', 'stanosta'], ['torieas', 'ras', 'niior', 'sesos', 'taeortae'], ['arsniet', 'set', 'onnrs', 'titrt', 'aeirsaei'], ['estonia', 'tia', 'roost', 'anasa', 'einstein']]
# Cyphered Message is English  estonia tia roost anasa einstein in RNN
# RNN execution time 0.00311279296875
# 5 out of  5 words is English
# Cyphered Message is English  estonia tia roost anasa einstein in DFA
# DFA execution time 0.0
# ononis torreon sonsie assessee teaser
# Try message in following list
#  [['srsroa', 'esttnsr', 'asraon', 'iaanaann', 'eniant'], ['tstsre', 'itaaots', 'etsero', 'neeoeeoo', 'ioneoa'], ['atatsi', 'naeerat', 'iatisr', 'oiiriirr', 'nroire'], ['eaeatn', 'oeiisea', 'neants', 'rnnsnnss', 'osrnsi'], ['ieieao', 'rinntie', 'oieoat', 'sootoott', 'rtsotn'], ['ninier', 'snooani', 'rnirea', 'trrarraa', 'satrao'], ['ononis', 'torreon', 'sonsie', 'assessee', 'teaser']]
# Cyphered Message is English  ononis torreon sonsie assessee teaser in RNN
# RNN execution time 0.015623092651367188
# 5 out of  5 words is English
# Cyphered Message is English  srsroa esttnsr asraon iaanaann eniant in DFA
# DFA execution time 0.0
# test stress terrorise soar satirise
# Try message in following list
#  [['enae', 'aetnaa', 'enttstoan', 'asit', 'aieotoan'], ['ioei', 'eiaoee', 'ioaatareo', 'etna', 'enirareo'], ['nrin', 'inerii', 'nreeaesir', 'iaoe', 'ionsesir'], ['osno', 'noisnn', 'osiieitns', 'neri', 'nrotitns'], ['rtor', 'orntoo', 'rtnninaot', 'oisn', 'osranaot'], ['sars', 'rsoarr', 'saoonoera', 'rnto', 'rtseoera'], ['test', 'stress', 'terrorise', 'soar', 'satirise']]
# Cyphered Message is English  test stress terrorise soar satirise in RNN
# RNN execution time 0.015621185302734375
# 5 out of  5 words is English
# Cyphered Message is English  test stress terrorise soar satirise in DFA
# DFA execution time 0.022043228149414062
# WOW
# era retrorse soon tanner inanition
# Try message in following list
#  [['nti', 'tnetstan', 'assr', 'eirrnt', 'oriroeosr'], ['oan', 'aoiataeo', 'etts', 'inssoa', 'rsnsrirts'], ['reo', 'erneaeir', 'iaat', 'nottre', 'stotsnsat'], ['sir', 'isoieins', 'neea', 'oraasi', 'taratotea'], ['tns', 'ntrninot', 'oiie', 'rseetn', 'aesearaie'], ['aot', 'oasonora', 'rnni', 'stiiao', 'eitieseni'], ['era', 'retrorse', 'soon', 'tanner', 'inanition']]
# Cyphered Message is English  era retrorse soon tanner inanition in RNN
# RNN execution time 0.017951488494873047
# Cyphered Message is English  era retrorse soon tanner inanition in DFA
# DFA execution time 0.0
# tinter arrester sennett serene rossetti
# Try message in following list
#  [['eorent', 'ittnaent', 'anrrnee', 'antnrn', 'tsaaneeo'], ['irsioa', 'naaoeioa', 'eossoii', 'eoaoso', 'ateeoiir'], ['nstnre', 'oeerinre', 'irttrnn', 'irertr', 'eaiirnns'], ['otaosi', 'riisnosi', 'nsaasoo', 'nsisas', 'iennsoot'], ['raertn', 'snntortn', 'oteetrr', 'otntet', 'niootrra'], ['seisao', 'tooarsao', 'raiiass', 'raoaia', 'onrrasse'], ['tinter', 'arrester', 'sennett', 'serene', 'rossetti']]
# Cyphered Message is English  tinter arrester sennett serene rossetti in RNN
# RNN execution time 0.013964176177978516
# 5 out of  5 words is English
# Cyphered Message is English  tinter arrester sennett serene rossetti in DFA
# DFA execution time 0.0
# assess arsine natation notornis rooter
# Try message in following list
#  [['iaanaa', 'itaorn', 'rieieosr', 'rsestroa', 'tssent'], ['neeoee', 'naerso', 'sninirts', 'stitasre', 'attioa'], ['oiirii', 'oeistr', 'tononsat', 'tanaetsi', 'eaanre'], ['rnnsnn', 'rintas', 'arorotea', 'aeoeiatn', 'ieeosi'], ['sootoo', 'snoaet', 'esrsraie', 'eirineao', 'niirtn'], ['trrarr', 'toreia', 'itstseni', 'insnoier', 'onnsao'], ['assess', 'arsine', 'natation', 'notornis', 'rooter']]
# Cyphered Message is English  assess arsine natation notornis rooter in RNN
# RNN execution time 0.01030731201171875
# Cyphered Message is English  assess arsine natation notornis rooter in DFA
# DFA execution time 0.0
# nonstarter rosiness trotter stairs nest
# Try message in following list
#  [['rsraeitent', 'tsaornaa', 'etseent', 'aeiota', 'rnae'], ['stseinaioa', 'atersoee', 'iatiioa', 'einrae', 'soei'], ['tatinoenre', 'eaistrii', 'neannre', 'inosei', 'trin'], ['aeanoriosi', 'ientasnn', 'oieoosi', 'nortin', 'asno'], ['eieorsnrtn', 'nioaetoo', 'rnirrtn', 'orsano', 'etor'], ['inirstosao', 'onreiarr', 'sonssao', 'rsteor', 'iars'], ['nonstarter', 'rosiness', 'trotter', 'stairs', 'nest']]
# Cyphered Message is English  nonstarter rosiness trotter stairs nest in RNN
# RNN execution time 0.015622138977050781
# 5 out of  5 words is English
# Cyphered Message is English  nonstarter rosiness trotter stairs nest in DFA
# DFA execution time 0.0
# resort arrester eater stannite tattoo
# Try message in following list
#  [['tnaste', 'ittnaent', 'nient', 'aeirroen', 'eieess'], ['aoetai', 'naaoeioa', 'onioa', 'einssrio', 'iniitt'], ['eriaen', 'oeerinre', 'ronre', 'inottsnr', 'nonnaa'], ['isneio', 'riisnosi', 'srosi', 'noraatos', 'orooee'], ['ntoinr', 'snntortn', 'tsrtn', 'orseeart', 'rsrrii'], ['oarnos', 'tooarsao', 'atsao', 'rstiiesa', 'stssnn'], ['resort', 'arrester', 'eater', 'stannite', 'tattoo']]
# Cyphered Message is English  resort arrester eater stannite tattoo in RNN
# RNN execution time 0.0
# 5 out of  5 words is English
# Cyphered Message is English  eriaen oeerinre ronre inottsnr nonnaa in DFA
# DFA execution time 0.0
# runtimes are equal
# accuracyRNN vs accuracyDFA 100.00% 100.00%

# %% [markdown]
# #### 3.4. Get stats
# Display the extracted DFA by using the `draw_nicely` function, which has optional parameters `maximum` (default $60$) and `force` (default `False`), and will only draw the DFA if it has less than `maximum` states or `force` is set to `True`.
#
# Print some statistics you might find interesting about the network, such as the trained RNN's accuracy against its target, the extracted DFA's accuracy against the RNN, and the extracted DFA's accuracy against the original RNN's target.

# %%
from math import pow
def percent(num,digits=2):
    tens = pow(10,digits)
    return str(int(100*num*tens)/tens)+"%"

dfaOpt.draw_nicely(maximum=300) #max size willing to draw

test_set = train_set 
print("testing on train set, i.e. test set is train set")
# we're printing stats on the train set for now, but you can define other test sets by using
# make_train_set_for_target

n = len(test_set)
print("test set size:", n)
pos = len([w for w in test_set if target(w)])
print("of which positive:",pos,"("+percent(pos/n)+")")
rnn_target = len([w for w in test_set if rnn.classify_word(w)==target(w)])
print("rnn score against target on test set:",rnn_target,"("+percent(rnn_target/n)+")")
dfa_rnn = len([w for w in test_set if rnn.classify_word(w)==dfa.classify_word(w)])
print("extracted dfa score against rnn on test set:",dfa_rnn,"("+percent(dfa_rnn/n)+")")
dfa_target = len([w for w in test_set if dfa.classify_word(w)==target(w)])
print("extracted dfa score against target on rnn's test set:",dfa_target,"("+percent(dfa_target/n)+")")
# Out:
# testing on train set, i.e. test set is train set
# test set size: 2042
# of which positive: 1031 (50.48%)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-50eca1df4867> in <module>()
#      16 pos = len([w for w in test_set if target(w)])
#      17 print("of which positive:",pos,"("+percent(pos/n)+")")
# ---> 18 rnn_target = len([w for w in test_set if rnn.classify_word(w)==target(w)])
#      19 print("rnn score against target on test set:",rnn_target,"("+percent(rnn_target/n)+")")
#      20 dfa_rnn = len([w for w in test_set if rnn.classify_word(w)==dfa.classify_word(w)])
#
# <ipython-input-11-50eca1df4867> in <listcomp>(.0)
#      16 pos = len([w for w in test_set if target(w)])
#      17 print("of which positive:",pos,"("+percent(pos/n)+")")
# ---> 18 rnn_target = len([w for w in test_set if rnn.classify_word(w)==target(w)])
#      19 print("rnn score against target on test set:",rnn_target,"("+percent(rnn_target/n)+")")
#      20 dfa_rnn = len([w for w in test_set if rnn.classify_word(w)==dfa.classify_word(w)])
#
# NameError: name 'rnn' is not defined

# %% [markdown]
# Rotation Cypher Checker
